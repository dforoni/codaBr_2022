# %%
import pandas as pd

# %%
dados = pd.read_csv('dados/remuneracao_202208.zip', sep=';', encoding='latin-1')
dados.head()
# Out:
#                          NOME                   CARGO  \
# 0     AAIRON TELES DE CAMARGO  OFICIAL ADMINISTRATIVO
# 1       AALAN DA SILVA ARAUJO                SD 1C PM
# 2  AARAN ESTEVAO LIMA BARBOSA                CAP   PM
# 3           AARAO DE OLIVEIRA                MAJ   PM
# 4      AARON DOUGLAS OLIVEIRA                CABO  PM
#
#                             ORGÃO REMUNERAÇÃO DO MÊS FÉRIAS E 13º SALÁRIO  \
# 0  DEPTO. EST. TRANSITO DETRAN SP            2645,13                 0,00
# 1       POLICIA MILITAR SAO PAULO            4469,53                 0,00
# 2       POLICIA MILITAR SAO PAULO           13135,95                 0,00
# 3  SAO PAULO PREVIDENCIA   SPPREV           17921,51                 0,00
# 4       POLICIA MILITAR SAO PAULO            5348,25                 0,00
#
#   PAGAMENTOS EVENTUAIS LICENÇA PRÊMIO INDENIZADA  \
# 0                 0,00                      0,00
# 1              5744,25                      0,00
# ...

# %%
dados.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1080819 entries, 0 to 1080818
# Data columns (total 11 columns):
#  #   Column                                   Non-Null Count    Dtype
# ---  ------                                   --------------    -----
#  0   NOME                                     1080819 non-null  object
#  1   CARGO                                    1080453 non-null  object
#  2   ORGÃO                                    1080819 non-null  object
#  3   REMUNERAÇÃO DO MÊS                       1080819 non-null  object
#  4   FÉRIAS E 13º SALÁRIO                     1080819 non-null  object
#  5   PAGAMENTOS EVENTUAIS                     1080819 non-null  object
#  6   LICENÇA PRÊMIO INDENIZADA                1080819 non-null  object
#  7   ABONO PERMANÊNCIA & OUTRAS INDENIZAÇÕES  1080819 non-null  object
#  8   REDUTOR SALARIAL                         1080819 non-null  object
#  9   TOTAL LIQUÍDO (R$)                       1080819 non-null  object
# ...
